# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
df = pd.read_csv('new_data.csv')
df
# Out:
#          Unnamed: 0               event_time event_type  product_id  \
# 0                 0  2019-11-01 00:00:00 UTC       view     1003461
# 1                 1  2019-11-01 00:00:00 UTC       view     5000088
# 2                 2  2019-11-01 00:00:01 UTC       view    17302664
# 3                 3  2019-11-01 00:00:01 UTC       view     3601530
# 4                 4  2019-11-01 00:00:01 UTC       view     1004775
# ...             ...                      ...        ...         ...
# 9999995     9999995  2019-11-07 05:08:21 UTC       view     1005115
# 9999996     9999996  2019-11-07 05:08:21 UTC       view    12707281
# 9999997     9999997  2019-11-07 05:08:21 UTC       view     3601405
# 9999998     9999998  2019-11-07 05:08:21 UTC       view    12711053
# 9999999     9999999  2019-11-07 05:08:21 UTC       cart     1005121
#
#                  category_id              category_code     brand   price  \
# 0        2053013555631882655     electronics.smartphone    xiaomi  489.07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Unnamed: 0     int64
#  1   event_time     object
#  2   event_type     object
#  3   product_id     int64
#  4   category_id    int64
#  5   category_code  object
#  6   brand          object
#  7   price          float64
#  8   user_id        int64
#  9   user_session   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 762.9+ MB

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0               event_time event_type    product_id  \
# count   1.000000e+07                 10000000   10000000  1.000000e+07
# unique           NaN                   523423          3           NaN
# top              NaN  2019-11-05 17:23:19 UTC       view           NaN
# freq             NaN                      113    9731128           NaN
# mean    5.000000e+06                      NaN        NaN  1.100008e+07
# std     2.886751e+06                      NaN        NaN  1.228346e+07
# min     0.000000e+00                      NaN        NaN  1.000365e+06
# 25%     2.500000e+06                      NaN        NaN  1.005252e+06
# 50%     5.000000e+06                      NaN        NaN  5.100722e+06
# 75%     7.499999e+06                      NaN        NaN  1.640001e+07
# max     9.999999e+06                      NaN        NaN  6.210003e+07
#
#          category_id           category_code    brand         price  \
# ...

# %%
df.groupby('brand')['price'].mean()
# Out:
# brand
# a-case                 14.556634
# a-derma                13.292632
# a-elita                50.412941
# a-mega                 73.707460
# aardwolf               65.116000
#                          ...
# zvezda                 42.650000
# zwerg                  23.295000
# zwilling              168.924000
# zwillingjahenckels    883.973300
# zyxel                 188.011220
# Name: price, Length: 3373, dtype: float64

# %%
import seaborn as sns
# find out the mean price of the brand that have been purchased by users
price_list = df[df['event_type'] == 'purchase'].groupby('brand')['price'].max().sort_values(ascending=False)

# %%
price_list[:20].plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
pltest = price_list.to_frame().iloc[:20].reset_index()

# %%
sns.barplot(data= pltest, x='brand', y='price')
# Out:
# <Axes: xlabel='brand', ylabel='price'>

# %%
pltest
# Out:
#          brand    price
# 0      samsung  2574.04
# 1         acer  2574.04
# 2         sony  2574.04
# 3          msi  2574.04
# 4         asus  2570.18
# 5        canon  2565.85
# 6         peda  2557.59
# 7      cartier  2555.28
# 8        apple  2548.07
# 9       garmin  2522.59
# 10          lg  2445.08
# 11         fly  2264.92
# 12          hp  2125.91
# 13       smart  2064.02
# 14    delonghi  2059.18
# 15      xiaomi  2033.51
# 16  minimotors  2033.51
# 17      daewoo  2032.77
# 18       cybex  1956.27
# 19    dynacord  1919.48

# %%
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# User Groups based on "viewing and adding smartphone in cart but never buying"

# Experiment:

# for A% of users, offering 10% discount
# for B% of users, offering free shipping
# for c% of users, offering nothing
